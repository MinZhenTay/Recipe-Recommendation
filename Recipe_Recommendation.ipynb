# %% [markdown]
# <a href="https://colab.research.google.com/github/MinZhenTay/Recipe-Recommendation/blob/main/Recipe_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Recipe Recommendation System using LDA Algorithm**

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import spacy

# %%
# Upload the Dataset
recipes = pd.read_csv('/Users/60197/Desktop/Research Project/FinalRecipeData.csv')

# %%
recipes.head()
# Out:
#    Unnamed: 0                           recipe_name  \
# 0           0        air fried raspberry brie bites
# 1           1  spicy chicken jerky in the air fryer
# 2           2    air fryer scrambled eggs on the go
# 3           3              basic air fryer hot dogs
# 4           4               air fryer potato wedges
#
#                                          ingredients  \
# 0  ['1 (8 ounce) round brie cheese', '1 (8 ounce)...
# 1  ['2 (5 ounce) boneless chicken breasts, cut in...
# 2  ['  cooking spray', '2 large eggs, beaten', ' ...
# 3                 ['4  hot dog buns', '4  hot dogs']
# 4  ['2 medium russet potatoes', '1 ½ tablespoons ...
#
#                                   cooking_directions  \
# 0  ['\nslice the brie into squares about ½ inch t...
# 1  ['\ncombine chicken strips, marinade, and caju...
# 2  ['\nlightly spray a ramekin dish with non-stic...
# 3  ['\npreheat an air fryer to 400 degrees f (200...
# 4  ['\npreheat an air fryer to 400 degrees f (200...
#
#                                           nutritions
# 0  [{'calories': '252'}, {'fat': '16g '}, {'carbs...
# 1  [{'calories': '54'}, {'fat': '1g '}, {'carbs':...
# 2  [{'calories': '143'}, {'fat': '10g '}, {'carbs...
# 3  [{'calories': '269'}, {'fat': '15g '}, {'carbs...
# 4  [{'calories': '129'}, {'fat': '5g '}, {'carbs'...

# %%
# Check if there is any missing value
missing_values = recipes.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0            0
# recipe_name           0
# ingredients           0
# cooking_directions    0
# nutritions            0
# dtype: int64

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\60197\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Remove stopwords
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))

# %%
# Preprocess the 'ingredients' column
recipes['ingredients'] = recipes['ingredients'].str.lower()
recipes['ingredients'] = recipes['ingredients'].str.replace('cup','')

# %%
recipes['ingredients'] = recipes['ingredients'].str.replace(r'[¼½⅓]','')
# Out:
# C:\Users\60197\AppData\Local\Temp/ipykernel_19132/3567012075.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   recipes['ingredients'] = recipes['ingredients'].str.replace(r'[¼½⅓]','')

# %%
# Join text for 'recipe_name', 'cooking_directions' & 'ingredients'
all_text = recipes['recipe_name'] + ' ' + recipes['ingredients'] + ' ' + recipes['cooking_directions']
all_text[0]
# Out:
# "air fried raspberry brie bites ['1 (8 ounce) round brie cheese', '1 (8 ounce) package phyllo dough, thawed', '1  raspberry jam', '1  butter, melted', '2 tablespoons honey', '  flakey salt to taste'] ['\\nslice the brie into squares about ½ inch thick and 1 to 1 ½ inches wide.\\n', '\\nroll out 1 sheet of phyllo dough vertically on a large work surface. brush the bottom half of the dough with melted butter, then fold the top half over onto itself.\\n', '\\nplace 1 piece of cheese in the bottom center of the dough, about 2 inches from the edges. spoon about 2 teaspoons raspberry jam onto the cheese. brush melted butter around the rest of the dough.\\n', '\\nfold in the bottom 2 inches of dough over the cheese, then fold in both sides. brush more butter onto the remaining dough, then carefully roll the filling upwards until it is wrapped fully. brush more butter on top and set into the air fryer try.\\n', '\\nset air fryer to 375 degrees f (190 degrees c).\\n', '\\nair fry in batches to avoid overcrowding until golden-brown, 4 to 5 minutes. garnish with a thin drizzle of honey and a pinch of flakey salt. serve immediately.\\n']"

# %%
# Clean_text Function
import string
import re

def clean_text(documents):
    cleaned_text = []
    for doc in documents:
        doc = doc.translate(str.maketrans('', '', string.punctuation)) # Remove punctuation
        doc = re.sub(r'\d+', '', doc) # Remove digits
        doc = doc.replace('\n',' ') # Remove new lines
        doc = doc.strip() # Remove Leading white space
        doc = re.sub(' +', ' ', doc) # Remove multiple white spaces
        cleaned_text.append(doc)
    return cleaned_text

# Clean text
cleaned_text = clean_text(all_text)

# %%
cleaned_text[2]
# Out:
# 'air fryer scrambled eggs on the go cooking spray large eggs beaten salt and freshly ground black pepper to taste nlightly spray a ramekin dish with nonstick cooking spray pour in beaten eggsn nset air fryer to degrees f degrees c and place the ramekin into the air fryer basketn nair fry for minutes stir egg mixture and cook for minutes more fluff with a fork and season to taste with salt and pepper grab and gon'

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

# %%
def lemmatize_stemming(text):
    stemmer = SnowballStemmer("english")
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\60197\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\60197\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
processed_text = [preprocess(text) for text in cleaned_text]

# %%
processed_text[2 ]
# Out:
# ['fryer',
#  'scrambl',
#  'egg',
#  'cook',
#  'spray',
#  'larg',
#  'egg',
#  'beat',
#  'salt',
#  'fresh',
#  'grind',
#  'black',
#  'pepper',
#  'tast',
#  'nlight',
#  'spray',
#  'ramekin',
#  'dish',
#  'nonstick',
#  'cook',
#  'spray',
#  'pour',
#  'beat',
#  'eggsn',
#  'nset',
#  'fryer',
#  'degre',
#  'degre',
#  'place',
#  'ramekin',
#  'fryer',
#  'basketn',
#  'nair',
#  'minut',
#  'stir',
#  'mixtur',
#  'cook',
#  'minut',
#  'fluff',
#  'fork',
#  'season',
#  'tast',
#  'salt',
#  'pepper',
#  'grab']

# %%
dictionary = gensim.corpora.Dictionary(processed_text)
corpus = [dictionary.doc2bow(text) for text in processed_text]

# %%
lda_model = gensim.models.LdaModel(corpus, 
                                   num_topics = 10, 
                                   id2word = dictionary,                                    
                                   passes = 10)
term_topic_weights = lda_model.get_topics()

# %%
def get_recommendations(ingredients, processed_text, dictionary, lda_model):
    ingredients_bow = dictionary.doc2bow(preprocess(ingredients))
    lda_topics = lda_model.get_document_topics(ingredients_bow)
    lda_topics = sorted(lda_topics, key=lambda x: x[1], reverse=True)
    top_topic = lda_topics[0][0]
    
    recommendations = []
    for index, row in enumerate(processed_text):
        topic_probs = lda_model.get_document_topics(dictionary.doc2bow(row))
        for topic in topic_probs:
            if topic[0] == top_topic and topic[1] > 0.5:
                recommendations.append(index)
    
    return recommendations

# %%
ingredients = "meat"
recommendations = get_recommendations(ingredients, processed_text, dictionary, lda_model)

# %%
recipe_names = [recipes['recipe_name'][index] for index in recommendations]

# %%
recipe_names
# Out:
# ['spicy chicken jerky in the air fryer',
#  'air fryer scrambled eggs on the go',
#  'basic air fryer hot dogs',
#  'air fryer potato wedges',
#  'air fryer meatballs',
#  'easy air fryer baked potatoes',
#  'air fryer roasted asparagus',
#  'air fryer chicken thighs',
#  'simple air fryer brussels sprouts',
#  'air fryer meatloaf',
#  'easy air fryer pork chops',
#  'air fryer sweet potato fries',
#  'air fryer roasted garlic',
#  'the best air fryer toaster ovens according to our tests',
#  'air fryer baked potatoes',
#  'air fryer sausage patties',
#  'air fryer tilapia with fresh lemon pepper',
#  'air fryer lobster tails with lemon garlic butter',
#  'air fryer chicken cordon bleu',
#  'air fryer roasted okra',
#  'crumbed chicken tenderloins air fried',
#  'air fryer rib eye steak',
#  'air fryer calamari',
#  'air fryer chicken katsu with homemade katsu sauce',
#  'air fryer hasselback potatoes',
#  'air fryer roasted bananas',
#  'air fryer eggplant parmesan',
#  'air fryer fingerling potatoes',
#  'air fryer rotisserie chicken',
#  'dry rub air fried chicken wings',
#  'homemade croutons in the air fryer',
#  'air fryer buttermilk fried chicken',
#  'breaded air fryer pork chops',
#  'air fryer bbq baby back ribs',
#  'easy air fried chicken breast',
#  'bacon wrapped stuffed chicken breasts in the air fryer',
#  'air fryer fried mushrooms',
#  'air fryer artichoke hearts',
#  'air fried crumbed fish',
#  'sole oreganata',
#  'air fryer orange cranberry butternut squash with ginger',
#  'air fryer spaghetti squash',
#  'grilled lemon pepper radishes',
#  'air fryer panko crusted pork chops',
#  'roasted french style potatoes',
#  'easy oven fried chicken legs',
#  'baked chicken wings',
#  'fried chicken wings',
#  'roasted green beans',
#  'docbest beef jerky',
#  'easy lemon pepper chicken wings',
#  'easy meatloaf',
#  'chef johnperfect prime rib',
#  'cast iron pan seared steak oven finished',
#  'juiciest hamburgers ever',
#  'lisafavorite carne asada marinade',
#  'beef bulgogi',
#  'best hamburger ever',
#  'best roast beef',
#  'marinated flank steak',
#  'high temperature eye of round roast',
#  'foolproof rib roast',
#  'easiest pot roast ever',
#  'the perfect basic burger',
#  'surf and turf for two',
#  'fabulous beef tenderloin',
#  'air fryer beef tenderloin',
#  'filet mignon with rich balsamic glaze',
#  'easy barbeque beef tenderloin steak',
#  'easy yet romantic filet mignon',
#  'mouthwatering crabmeat pan seared filets',
#  'filet mignons with pepper cream sauce',
#  'lobster colorado',
#  'confit olive oil steak',
#  'blue cheese beef tenderloin',
#  'loverbeef burgundy filet',
#  'smothered filet mignon',
#  'filet mignon for two',
#  'broiled filet mignon',
#  'filet mignon and balsamic strawberries',
#  'herb and garlic roast tenderloin with creamy horseradish sauce',
#  'herbed and spiced roasted beef tenderloin',
#  'louiseherbed beef tenderloin',
#  'sesame beef bites',
#  'homemade breakfast sausage',
#  'air fryer seasoned breakfast potatoes',
#  'citrus turkey brine',
#  'orange turkey brine',
#  'dry brine turkey',
#  'thanksgiving turkey brine',
#  'buttermilk brined turkey',
#  'spice rubbed chicken leg quarters',
#  'brined thanksgiving turkey',
#  'brined turkey',
#  'dry brined turkey',
#  'orange tea bourbon brined paprika butter turkey',
#  'bruschetta al pomodoro',
#  'bruschetta with roasted sweet red peppers',
#  'air fryer buffalo chicken wings from frozen',
#  'air fryer buffalo wings',
#  'home style buffalo wings',
#  'panko buffalo chicken tenders',
#  'actually delicious buffalo turkey burgers',
#  'spicy beef bulgogi',
#  'natashachicken burgers',
#  'lamb burgers',
#  'grilled bison burgers',
#  'seasoned turkey burgers',
#  'air fryer hamburger patties',
#  'spinach and feta turkey burgers',
#  'air fryer burgers',
#  'almost white castle hamburgers',
#  'venison bacon burgers',
#  'delicious grilled hamburgers',
#  'blue cheese burgers',
#  'pan fried turkey burgers',
#  'ranch burgers',
#  'fresh salmon burgers in the air fryer',
#  'ground chicken burgers',
#  'garlic and onion burgers',
#  'juicy lucy burgers',
#  'all american burger dog',
#  'air fryer bison burgers',
#  'grilled lamb burgers',
#  'cheddar bacon hamburgers',
#  'the juiciest hamburgers ever',
#  'feta stuffed hamburgers',
#  'turkey patties',
#  'air fryer venison burgers',
#  'air fryer cheeseburgers',
#  'jalapeno garlic onion cheeseburgers',
#  'black bean turkey burgers',
#  'my husbandfavorite baked burgers',
#  'breaded hamburgers',
#  'moist spicy turkey burgers',
#  'slow cooker hamburgers',
#  'pesto turkey burgers',
#  'bacon wrapped hamburgers',
#  'chef johngrilled bacon meatloaf burgers',
#  'grilled cheese patty melts',
#  'campfire baked potatoes',
#  'lesliesalty grilled potatoes',
#  'grilled tomatoes',
#  'campfire foil packs',
#  'beets on the grill',
#  'awesome grilled walleye scooby snacks',
#  'caramelized onions on the grill',
#  'barbarian beef',
#  'chicken fried venison steaks',
#  'barbequed cabbage',
#  'eggs on the grill',
#  'grilled chicken and potato foil packs',
#  'grilled sausage with potatoes and green beans',
#  'campfire trout',
#  'crispy garlic crumb steak',
#  'oven baked baby back ribs',
#  'how to cookturkey',
#  'greek lemon chicken and potatoes',
#  'roasted delicata squash',
#  'homemade beef jerky',
#  'teriyaki chicken cordon bleu',
#  'quick crispy parmesan chicken breasts',
#  'oven fried parmesan chicken',
#  'parmesan chicken legs',
#  'grandmas bogieparmesan chicken',
#  'air fryer parmesan chicken bites',
#  'teriyaki chicken',
#  'grilled teriyaki chicken tenders',
#  'grilled teriyaki beer chicken',
#  'teriyaki chicken thigh skewers',
#  'grilled teriyaki salmon',
#  'doreenteriyaki steak marinade',
#  'char siu chinese bbq pork',
#  'chinese spareribs',
#  'chinese chicken wings',
#  'french canadian tourtière',
#  'a simply perfect roast turkey',
#  'honey glazed ham',
#  'tangy honey glazed ham',
#  'baked ham',
#  'perfect baked potato',
#  'roasted new red potatoes',
#  'oven roasted potatoes',
#  'homemade pita chips',
#  'savory pan seared tuna steaks',
#  'easy baked ham steaks',
#  'broiled lobster tails',
#  'how to cook trout',
#  'parchment baked salmon',
#  'applesauce pork chops',
#  'lemon rosemary salmon',
#  'broiled scallops',
#  'oh my arctic char',
#  'baked halibut with crispy panko',
#  'parmesan crusted pork chops',
#  'miso glazed black cod',
#  'perfect porterhouse steak',
#  'lemon panko crusted salmon',
#  'pan fried wild salmon',
#  'cajun air fryer salmon',
#  'easy no mess baked salmon',
#  'seafood bake for two',
#  'easy mediterranean baked chicken breast',
#  'grilled salmon steaks italian style',
#  'breaded and fried scallops',
#  'grilled salmon with maple syrup and soy sauce',
#  'sea bass barbecue',
#  'baked split chicken breast',
#  'southern fried catfish',
#  'roasted turkey legs',
#  'fish in foil',
#  'grilled pork loin chops',
#  'grilled fish steaks',
#  'emilymarinated venison steaks',
#  'baked salmon',
#  'pickle brine chicken',
#  'the original donair from the east coast of canada',
#  'shrimp de jonghe',
#  'braised corned beef brisket',
#  'easy homemade pastrami',
#  'corned beef roast',
#  'guinness corned beef',
#  'smoked corned beef brisket',
#  'a slice of heaven baked corned beef',
#  'janbeer brined corned beef',
#  'air fryer cajun crab cakes',
#  'grammycrab cakes',
#  'lemon orange orange roughy',
#  'air fryer garlic and parsley baby potatoes',
#  'superfast asparagus',
#  'grilled butternut squash',
#  'prosciutto wrapped pork tenderloin with crispy sage',
#  'juicy roasted chicken',
#  'roasted pork loin',
#  'turkey insmoker',
#  'juicy thanksgiving turkey',
#  'oven roasted turkey breast',
#  'roast spatchcock turkey',
#  'marinated tuna steak',
#  'simple deep fried turkey',
#  'roasted rack of lamb',
#  'grilled salmon',
#  'chef johntandoori chicken',
#  'brown sugar and pineapple glazed ham',
#  'baked salmon fillets dijon',
#  'asparagus wrapped in crisp prosciutto',
#  'roast leg of lamb',
#  'home cured holiday ham',
#  'salmon with lemon and dill',
#  'grilled eggplant parmesan',
#  'eggplant parmesan bites',
#  'air fryer steak for fajitas',
#  'sheet pan beef fajitas',
#  'easy flank steak fajitas',
#  'grilled chicken fajitas',
#  'sizzlin fajitas',
#  'grilled steak fajitas',
#  'melt in your mouth beef fajitas',
#  'easy steak and shrimp fajitas',
#  'sirloin steak with garlic butter',
#  'grilled tri tip',
#  'mombeef shish kabobs',
#  'simple grilled lamb chops',
#  'restaurant style prime rib roast',
#  'beer butt chicken',
#  'chef johnbarbecue chicken',
#  'cornell chicken',
#  'grilled delmonico steaks',
#  'firecracker fried chicken drumsticks',
#  'rockt bone steaks',
#  'grilled filet mignon with blue cheese butter',
#  'herb marinated tenderloin',
#  'flank steak pinwheels',
#  'rolled flank steak',
#  'london broil i',
#  'thai beef',
#  'grilled balsamic and soy marinated flank steak',
#  'grilled mexican steak',
#  'teriyaki steak',
#  'gflank steak marinade',
#  'overnight marinated flank steak',
#  'tuscan flank steak',
#  'flank steak marinade',
#  'sous vide marinated flank steak',
#  'broiled flank steak',
#  'tender flank steak',
#  'grilled or fried skirt steak',
#  'tacos de carne asada',
#  'flank steak barbecue',
#  'sous vide flank steak',
#  'braised flank steak in the oven',
#  'grilled flank steak',
#  'spicy flank steak',
#  'beerbecue beef flank steak',
#  'greek flank steak',
#  'marinated flank steak with horseradish cream',
#  'marinated grilled flank steak',
#  'stuffed flank steak in the oven',
#  'tex mex grilled flank steak',
#  'grilled sesame steak',
#  'baked flank steak roulade stuffed with bacon and cheese',
#  'garlic fennel flank steak with oranges',
#  'teriyaki flank steak',
#  'grilled chili flank steak with chipotle tomatillo salsa',
#  'grilled flat iron steak with blue cheese chive butter',
#  'foolproof flat iron steaks',
#  'roasted garlic flat iron steak',
#  'asian flat iron steak',
#  'easy flat iron steak in wine sauce',
#  'flat iron steak with three pepper rub',
#  'flat iron steaks marinated in red wine',
#  'flat iron grilled',
#  'drunken flat iron steak',
#  'asian flair flat iron steak',
#  'flat iron steak grilled totea',
#  'italian seasoning',
#  'oven fried chicken',
#  'air fried breaded chicken thighs',
#  'amazingly tasty and crispy chicken schnitzel',
#  'air fryer chicken wings',
#  'air fryer cornflake chicken fingers',
#  'air fryer chicken katsu',
#  'crisp fried chicken wings',
#  'air fryer fried chicken',
#  'crispy air fried chicken',
#  'baked french fries',
#  'best baked french fries',
#  'oven baked garlic and parmesan fries',
#  'chef johncottage fries',
#  'air fryer fries',
#  'air fryer truffle fries',
#  'cajun potato wedges',
#  'oven fries',
#  'air fryer okra fries',
#  'mojo french fries',
#  'duck fat steak fries',
#  'cajun baked french fries',
#  'air fryer frozen french fries',
#  'air fryer salt and vinegar fries for one',
#  'quick and easy parmesan zucchini fries',
#  'air fryer fish and chips',
#  'sweet and spicy air fried sweet potatoes',
#  'french fries in the air fryer',
#  'super easy oven baked garlic parmesan fries',
#  'air fryer peri peri fries',
#  'air fryer tajin sweet potato fries',
#  'baked french fries ii',
#  'chinese five spice air fryer butternut squash fries',
#  'air fryer asparagus fries',
#  'spicy old bay skinny fries',
#  'roasted sweet potato wedges',
#  'butternut squash cajun fries',
#  'zucchini fries',
#  'curried cottage fries',
#  'charlottebutternut squash fries',
#  'emergency garlic bread',
#  'homemade garlic bread',
#  'parmesan garlic bread',
#  'easy cheesy garlic bread',
#  'garlic bread fantastique',
#  'just garlic toast',
#  'fried garlic pita',
#  'lisabest ever garlic bread',
#  'herbed garlic bread',
#  'grilled asparagus',
#  'prize winning baby back ribs',
#  'grilled sea bass',
#  'beef pot roast',
#  'mayo chicken',
#  'serbian ćevapčići',
#  'super grouper',
#  'roast leg of lamb with rosemary',
#  'grilled marinated shrimp',
#  'grilled hearts of romaine',
#  'meatball sandwich',
#  'traditional gyro meat',
#  'chicken meatballs',
#  'cheesy chicken meatballs',
#  'chicken and feta burgers',
#  'greek chicken burgers with feta',
#  'baked chicken burgers with mushrooms and spinach',
#  'ginger chicken meatballs',
#  'baked chicken burger',
#  'all white meat meatloaf',
#  'kofta kebabs',
#  'kabob koobideh persian ground meat kabobs',
#  'baked lamb meatballs',
#  'gyros',
#  'american gyros',
#  'spicy lamb patties',
#  'lamb meatballs and sauce',
#  'authentic turkish doner kebab',
#  'lamb loaf',
#  'grilled spicy lamb burgers',
#  'gyros burgers',
#  'lamb sliders',
#  'mediterranean lamb burgers',
#  'greek lamb feta burgers with cucumber sauce',
#  'easy lamb gyros',
#  'chef johnkofta kebabs',
#  'feta and olive meatballs',
#  'kifta and potatoes with tahini sauce',
#  'persian inspired meatballs',
#  'kefta',
#  'merguez meatballs',
#  'homemade sweet italian sausage mild or hot',
#  'bulk venison breakfast sausage',
#  'meat pie tourtiere',
#  'my favorite pork turkey meatloaf',
#  'turkey breakfast sausage',
#  'momturkey sausage patties',
#  'baked turkey meatballs',
#  'italian turkey meatballs',
#  'homemade turkey breakfast sausage',
#  'turkey salisbury steak',
#  'italian style turkey meatloaf',
#  'gluten free turkey meatballs',
#  'mozzarella stuffed pesto turkey meatballs',
#  'turkey beef meatloaf',
#  'asian turkey burgers',
#  'turkish kebabs',
#  'venison gyros',
#  'chicken gyros',
#  'easy baked beef brisket',
#  'simply the easiest beef brisket',
#  'amazing oven roasted potatoes',
#  'roast chicken with rosemary',
#  'oh so tender brisket',
#  'grandmabrisket',
#  'oven barbecued beef brisket i',
#  'stuffed acorn squash',
#  'oklahoma brisket',
#  'oven kalua pork',
#  'huli huli chicken',
#  'lau lau',
#  'maple salmon',
#  'easy baked tilapia',
#  'slow cooker baked potatoes',
#  'baked sweet potatoes',
#  'brazilian grilled pineapple',
#  'baked honey mustard chicken',
#  'oven roasted red potatoes and asparagus',
#  'authentic kicked up syrian hummus',
#  'instant pot meatloaf',
#  'easy italian chicken',
#  'deer poppers',
#  'grilled pheasant poppers',
#  'sweet and spicy venison jerky',
#  'beef jerky insmoker',
#  'venison jerky',
#  'air fryer oven beef jerky',
#  'spicy salmon jerky',
#  'teriyaki beef jerky',
#  'air fryer steak jerky',
#  'air fryer oven pork jerky',
#  'dylansalmon jerky',
#  't birdbeef jerky',
#  'beef or moose jerky',
#  'mesquite smoked jerky',
#  'spicy beef jerky',
#  'swensmokehouse beef jerky',
#  'sumneydeer jerky',
#  'griswolds turkey jerky',
#  'sarabeef jerky',
#  'mckagenbeef jerky',
#  'moroccan shabbat fish',
#  'best turkey burgers',
#  'simple bbq ribs',
#  'grilled pineapple',
#  'baby back ribs',
#  'greek chicken',
#  'kalbi marinated beef short ribs',
#  'easy and simple korean bbq ribs',
#  'kalbi korean bbq short ribs authentic recipe',
#  'korean bbq inspired short ribs',
#  'smoked chicken drumsticks',
#  'baked lemon butter chicken thighs',
#  'air fryer blackened chicken breasts',
#  'tuscan pork tenderloin',
#  'bacon on the grill',
#  'baked spaghetti squash',
#  'garlic butter smoked shrimp',
#  'smoked pork chops',
#  'roasted leg of pork',
#  'lemon garlic air fryer salmon',
#  'air fryer keto pork chops',
#  'air fryer ranch pork chops',
#  'easy sheet pan roasted cauliflower with curry',
#  'kalbi korean bbq short ribs',
#  'easy sheet pan beef bulgogi',
#  'spicy korean ribs',
#  'deep fried turkey',
#  'baked haddock',
#  'heavenly halibut',
#  'roasted okra',
#  'detroit hot honey wings',
#  'traditional gyros',
#  'oven roasted lamb chops',
#  'braised lamb shoulder chops',
#  'roasted lamb breast',
#  'grilled lamb loin chops',
#  'pistachio crusted rack of lamb',
#  'grilled leg of lamb steaks',
#  'slow cooker roasted leg of lamb',
#  'easy leg of lamb',
#  'baked lamb chops',
#  'chef johngrilled lamb steaks',
#  'broiled and slow roasted butterflied leg of lamb with cumin and garlic',
#  'lamb ribs with honey and wine',
#  'lamb souvlaki',
#  'lamb shank',
#  'grilled lamb with brown sugar glaze',
#  'oven roasted lamb ribs',
#  'stuffed leg of lamb',
#  'lemony steamed fish',
#  'roasted onions',
#  'roasted asparagus with parmesan',
#  'miso and soy chilean sea bass',
#  'cabbage steaks',
#  'bourbon chicken',
#  'lemon garlic tilapia',
#  'roast potatoes',
#  'baked bbq chicken tenders',
#  'marinated turkey breast',
#  'ginger glazed mahi mahi',
#  'oven baked potato slices',
#  'roasted cabbage',
#  'oven baked potato fries',
#  'tri tip roast',
#  'baked salmon in foil',
#  'hoisin glazed salmon',
#  'garlic bread spread',
#  'easy rib eye roast',
#  'santa maria grilled tri tip beef',
#  'cross rib roast',
#  'bacon wrapped turkey',
#  'stuffing meatloaf',
#  'brined and roasted whole turkey',
#  'sandysummer sausage',
#  'cajun deep fried turkey',
#  'turducken',
#  'bourbon glazed ham',
#  'honey orange glazed ham',
#  'pork chops with apples onions and sweet potatoes',
#  'blackened fish',
#  'blackened salmon fillets',
#  'cajun blackened catfish',
#  'cajun style blackened snapper',
#  'blackened tuna',
#  'cajun chicken',
#  'crispy fried fish',
#  'spicy honey peanut baked chicken thighs',
#  'oven baked chicken and vegetables in foil',
#  'the best meatballs you ll ever have',
#  'meatball nirvana',
#  'air fryer salmon nuggets',
#  'easy meatballs',
#  'gluten free italian meatballs',
#  'giant bacon wrapped meatballs',
#  'air fryer pork meatballs',
#  'how to cook frozen meatballs in the air fryer',
#  'fabiennebison meatballs',
#  'best turkey meatloaf',
#  'the best meatloaf',
#  'classic meatloaf',
#  'cheeseburger meatloaf',
#  'super moist meatloaf',
#  'low carb meatloaf with pork rinds',
#  'mushroom meatloaf',
#  'meatloaf for tomato haters',
#  'easy salsa meatloaf',
#  'marymeatloaf',
#  'italian style meatloaf i',
#  'grilled bbq meatloaf',
#  'jackiespecial meatloaf',
#  'incredibly cheesy turkey meatloaf',
#  'my meatloaf',
#  'jalapeno popper stuffed meatloaf',
#  'dadcheesy bacon wrapped meat loaf',
#  'bacon wrapped meatloaf',
#  'greek style potatoes',
#  'shrimp in foil',
#  'mediterranean chicken sheet pan dinner',
#  'broiled spanish mackerel',
#  'grilled sweet potato wedges',
#  'garlic and herb marinade',
#  'grilled tuna',
#  'italian grilled eggplant with basil and parsley melanzane grigliate al basilicoprezzemolo',
#  'easy chicken fajita marinade',
#  'bacon wrapped venison tenderloin with garlic cream sauce',
#  'pork butt roast with vegetables',
#  'stuffed pork tenderloin',
#  'roasted asparagus and mushrooms',
#  'stuffed pork loin',
#  'roasted yams',
#  'roasted vegetable medley',
#  'pork and sauerkraut',
#  'artichoke hearts gratin',
#  'homemade poultry seasoning',
#  'perfect flat iron steak',
#  'baked fresh rainbow trout',
#  'daddy eddieroast pork pernil puerto rican style',
#  'grilled beef tenderloin with herb garlic pepper coating',
#  'best salmon bake',
#  'southern style neck bones',
#  'herb rubbed sirloin tip roast',
#  'bacon for the family orcrowd',
#  'grilled turkey cuban sandwiches',
#  'cornish game hens with garlic and rosemary',
#  'roast sticky chicken rotisserie style',
#  'garlic prime rib',
#  'garlic red potatoes',
#  'simple whole roasted chicken',
#  'spicy rapid roast chicken',
#  'baked tilapia in garlic and olive oil',
#  'fantastic lemon butter fillet',
#  'roasted lemon herb chicken',
#  'roasted vegetable chicken',
#  'wine braised beef brisket',
#  'pesto crusted grouper',
#  'italian pesto roasted chicken',
#  'sweet potato chews for dogs',
#  'smoked eggs',
#  'air fryer polenta fries',
#  'air fried cajun polenta fries',
#  'worldbest honey garlic pork chops',
#  'slow cooker baby back ribs',
#  'bbq country style ribs',
#  'easy marinated pork tenderloin',
#  'tender pork spare ribs',
#  'oven fried pork chops',
#  'marinated baked pork chops',
#  'german pork chops and sauerkraut',
#  'best pork chop marinade',
#  'breaded baked pork chops',
#  'simple time pork chops',
#  'easy baked bbq pork chops',
#  'best grilled pork chops',
#  'pork rub rubbed and baked pork chops',
#  'honey mustard pork chops',
#  'asian marinated pork chops',
#  'perfect simple roasted pork chops',
#  'air fryer tonkatsu',
#  'broiled pork chops',
#  'chinese pork chops',
#  'oven baked stuffed pork chops',
#  'slow cooker pork chops',
#  'garlic seasoned baked pork chops',
#  'mombest pork chops',
#  'sticky garlic pork chops',
#  'moist baked pork chops',
#  'canadian pork loin chops',
#  'dry rub for ribs',
#  'grilled country style ribs',
#  'boiled baked ribs',
#  'oven baked barbecue rib tips',
#  'instant pot baby back ribs',
#  'barbecue ribs',
#  'honey garlic ribs',
#  'easy st louis style pork ribs on gas grill',
#  'oven baked bbq ribs',
#  'slow cooker pork rib tips',
#  'sweet smoked pork ribs',
#  'quick baby back ribs',
#  'salt and pepper spare ribs',
#  'spareribs and kraut',
#  'traditional rub for st louis ribs',
#  'barbequed ribs',
#  'air fryer baby back ribs',
#  'greek ribs',
#  'bbq country style pork ribs sous vide',
#  'southern grilled barbecued ribs',
#  'texas pork ribs',
#  'chef johncopycat mcrib sandwich',
#  'chinese five spice spare ribs',
#  'pineapple sticky ribs',
#  'bourbon bbq glazed baby back ribs',
#  'stuffed ribs',
#  'baby back ribs smoked to perfection',
#  'slow smoked pulled pork boston butt',
#  'crispy pork carnitas',
#  'cuban style roast pork',
#  'st louis pork steaks',
#  'easy oven pulled pork',
#  'wine and garlic pork portuguese vina dosh',
#  'chef johnpulled pork bbq',
#  'barbecued pork skewers',
#  'pork agrodolce',
#  'chef johnpaper pork shoulder',
#  'danfallin apart pork pot roast with cracked pepper gravy',
#  'chef johnporchetta',
#  'porchetta italiana',
#  'asian pork tenderloin',
#  'slow cooked pork tenderloin',
#  'pork tenderloin with apples and onions',
#  'honey glazed pork tenderloin',
#  'bacon wrapped pork medallions',
#  'grilled pork tenderloin',
#  'souvlaki',
#  'easy and elegant pork tenderloin',
#  'breaded pork tenderloin',
#  'apricot pork tenderloin',
#  'southern pork tenderloin',
#  'brown sugar and balsamic glazed pork tenderloin',
#  'air fryer mustard crusted pork tenderloin with potatoes and green beans',
#  'marinated grilled pork tenderloin',
#  'stuffed and rolled pork tenderloin',
#  'cheese stuffed pork tenderloin',
#  'orange marinated pork tenderloin',
#  'slow cooker pork tenderloin and potatoes',
#  'grilled pork tenderloin with balsamic honey glaze',
#  'maple garlic marinated pork tenderloin',
#  'pork tenderloin diablo',
#  'pork tenderloin',
#  'roasted pork tenderloin',
#  'bacon wrapped stuffed pork tenderloin',
#  'burgundy pork tenderloin',
#  'marinated pork tenderloin',
#  'rosemary pork roast',
#  'parsley and parmesan crusted pork tenderloin',
#  'pork tenderloin with dijon marsala sauce',
#  'pepper jelly pork',
#  'tangy grilled pork tenderloin',
#  'pot roast',
#  'oven bag pot roast',
#  'awesome red wine pot roast',
#  'easy pot roast',
#  'grandmabest pot roast',
#  'boliche cuban pot roast',
#  'my favorite pot roast',
#  'apple flavored pot roast',
#  'autumn pot roast ii',
#  'easy air fryer latkes',
#  'reverse sear prime rib roast',
#  'smoked prime rib roast',
#  'christmas prime rib',
#  'easy standing rib roast',
#  'kosher salt encrusted prime rib roast',
#  'cast iron skillet prime rib roast and gravy',
#  'the perfect prime rib roast',
#  'prime rib',
#  'prime rib iteasier than you think',
#  'the best prime rib ever',
#  'easy prime rib roast',
#  'prime rib roast on charcoal grill',
#  'rosemary dijon prime rib',
#  'rock salt roast prime rib',
#  'amazing slow roasted prime rib',
#  'kimprime rib',
#  'delectable prime rib au jus',
#  'rock salt encrusted prime rib',
#  'boneless garlic and rosemary rubbed prime rib with red wine mushroom sauce',
#  'best prime rib roast',
#  'blackened prime rib',
#  'smoked standing rib roast',
#  'delicious and easy prime rib',
#  'briangarlicky prime rib',
#  'holiday standing rib roast',
#  'boneless prime rib au poivre',
#  'sous vide prime rib',
#  'dutch oven pulled pork',
#  'smoked pork butt',
#  'super easy pulled pork sandwiches',
#  'fayepulled barbecue pork',
#  'easy shredded pork',
#  'simple smoked pork butt',
#  'north carolina style pulled pork',
#  'pineapple pulled pork al pastor',
#  'garlicky pumpkin seeds',
#  'simple baked chicken breasts',
#  'pan seared tilapia',
#  'simple broiled haddock',
#  'easy baked chicken tenders',
#  'baked chicken schnitzel',
#  'baked flounder with panko and parmesan',
#  'parmesan crusted tilapia fillets',
#  'baked fish fillets',
#  'crispy baked walleye',
#  'grilled bbq short ribs with dry rub',
#  'insane oven beef ribs',
#  'tanyaboneless short ribs',
#  'consommé pork chops',
#  'great garlic knots',
#  'top sirloin roast',
#  'pork roast with the worldbest rub',
#  'tender eye of round roast',
#  'simple savory pork roast',
#  'dadbasic moist pork roast',
#  'porketta roast',
#  'maple brined pork loin',
#  'balsamic roasted pork loin',
#  'hot honey chicken',
#  'honey baked chicken ii',
#  'honey roasted red potatoes',
#  'orange honey garlic chicken',
#  'cardamom maple salmon',
#  'honey chicken',
#  'grilled halibut ii',
#  'poor manhamburger steaks',
#  'family beef salisbury steak',
#  'easy salisbury steak',
#  'amish salisbury steak',
#  'sorta salisbury steak',
#  'broiled salisbury steaks',
#  'baked salisbury steak',
#  'melt in your mouth broiled salmon',
#  'baked dijon salmon',
#  'balsamic glazed salmon fillets',
#  'sweet glazed salmon',
#  'teriyaki salmon',
#  'pistachio crusted salmon',
#  'salmon with brown sugar glaze',
#  'mediterranean salmon',
#  'salmon patties with dill sauce',
#  'air fryer salmon from frozen',
#  'air fryer salmon croquettes',
#  'baked salmon steak',
#  'fire roasted cherry tomato salsa',
#  'beef on weck',
#  'venison salami',
#  'bellarosemary red potatoes',
#  'garlic salmon',
#  'shrimp scampi bake',
#  'sweet potato wedges with rosemary orange brown butter',
#  'roasted turnips',
#  'roasted brussels sprouts',
#  'oven roasted asparagus',
#  'simple roasted butternut squash',
#  'oven roasted sweet potatoes',
#  'old fashioned onion rings',
#  'slab pies make feedingthanksgiving crowd easy',
#  'pork burger sliders with peach tarragon aioli',
#  'cocktail meatballs',
#  'sous vide steak',
#  'sous vide blade roast with au jus',
#  'sous vide whole turkey',
#  '72 hour sous vide short ribs',
#  'sous vide cod',
#  'sous vide pork back ribs',
#  't bone steaks with red wine sauce',
#  'sous vide turkey breast',
#  'smoked turkey',
#  'smoked chicken thighs',
#  'perfect pita chips',
#  'grilled chicken fajita salad',
#  'arrachera mexican skirt steak for tacos',
#  'air fryer crispy fish tacos with slaw',
#  'deeroast pork for tacos',
#  'grill master chicken wings',
#  'bbq turkey',
#  'slow roasted bbq beef roast',
#  'grilled rock lobster tails',
#  'grilled soy sesame asparagus',
#  'grilled teriyaki tuna',
#  'roasted oranges with thyme',
#  'chili lime chicken',
#  'tex mex burger with cajun mayo',
#  'tex mex air fryer hash browns',
#  'no ordinary meatloaf',
#  'marksurprise meatloaf',
#  'easy beginnerturkey with stuffing',
#  'turkey brine',
#  'baked butternut squash',
#  'air fryer tofu',
#  'italian tofu meatballs',
#  'eggplant tomato salad',
#  'turkey inbag',
#  'perfect turkey',
#  'herb roasted turkey thighs',
#  'gas grill turkey',
#  'grilled cauliflower steaks',
#  'roasted carrots with garlic bread crumbs',
#  'cauliflower steaks',
#  'roasted parsnips',
#  'roasted turnips and carrots',
#  'roasted fall vegetables with rosemary',
#  'roasted baby potatoes',
#  'honey roasted carrots',
#  'roasted garlic parmesan fingerling potatoes',
#  'jo jo potatoes',
#  'roasted chickpeas',
#  'easy fried eggplant',
#  'greek style lemon roasted potatoes',
#  'air fried purple yam fries with sour cream sriracha sauce',
#  'grilled yams',
#  'baked yam fries with dip',
#  'mashed purple sweet potatoes',
#  'pork loin apples and sauerkraut',
#  'foolproof rosemary chicken wings',
#  'turkey black bean burgers',
#  'carolina pork twirl',
#  'chinese pot roast',
#  'biggest bestest burger',
#  'italian chicken with garlic and lemon',
#  'roasted loin of pork with pan gravy',
#  'juicy butt steaks',
#  'steak onstick',
#  'chicken crumb coating',
#  'garlic ginger chicken wings',
#  'chicken fried steak cuban style',
#  'asian beef skewers',
#  'new york spiedies',
#  'grilling thick steaks the reverse sear',
#  'char siu pork',
#  'cranberry stuffed turkey breasts',
#  'citrus marinated cuban pork chops',
#  'tropical grilled chicken breast',
#  'oven fried chicken ii',
#  'pesto stuffed pork chops',
#  'baked nashville hot chicken breasts',
#  'easy lovely lemon chicken',
#  'northern stuffed burgers',
#  'lighter meatloaf',
#  'beef crack flanken style short ribs',
#  'glazed baked ham',
#  'meal in foil',
#  'banana meatloaf',
#  'super simple oven barbequed chicken',
#  'melissaturkey meatloaf',
#  'grilled flank steak pastrami',
#  'lemon stuffed chicken',
#  'grillhaxe grilled eisbein pork shanks',
#  'steak tip marinade',
#  'blue cheese chipotle venison burgers',
#  'roasted cinnamon chicken',
#  'yakitori chicken',
#  'delicious turkey burgers',
#  'fried turkey wings',
#  'easy smoked turkey',
#  'roasted beer butt lime chicken',
#  'mock filets',
#  'marinated rosemary chicken',
#  'chinese roasted chicken',
#  'delectable marinated chicken',
#  'basil burgers',
#  'cottage meatloaf',
#  'fast grilled chicken breast marinade',
#  'roast beef and yorkshire pudding',
#  'chef johngrilled jerk pork tenderloin',
#  'amazing ribs',
#  'rotisserie chicken',
#  'cuban pork roast ii',
#  'drunk chicken',
#  'blue cheese and beef meatballs',
#  'feta cheese turkey burgers',
#  'caesar grilled chicken wings',
#  'grilled italian hamburgers',
#  'savory beefy burgers',
#  'overnight pork roast with cabbage',
#  'simple lasagna burgers',
#  'juicy deer and bacon burgers',
#  'beer roasted lime chicken',
#  'roasted lamb with root vegetables',
#  'apple cranberry stuffed pork chops',
#  'bourbon street rib eye steak',
#  'smothered pheasant',
#  'flank steak roulade',
#  'barbecued korean ribs',
#  'grilled turkey breast with fresh sage leaves',
#  'baked kielbasa and potatoes in sauce',
#  'pork chops with sweet mustard sauce',
#  'gourmet stuffed pork chops',
#  'beer can chicken',
#  'baked bbq meatballs',
#  'the very best burgers',
#  'isaacjuicy chicken',
#  'sweet spicy asian style bbq back ribs',
#  'maple and garlic marinated pork tenderloin',
#  'macmagnificent meatloaf',
#  'hawaiian burgers',
#  'crispy roasted chicken',
#  'italian rib eye',
#  'comforting cube steaks',
#  'teriyaki bacon wrapped scallops',
#  'baked brisket',
#  'steakhouse ribs new york style',
#  'ccrydercider smoked ribs',
#  'tangy grilled beef',
#  'ed ziebafamous family pork chops',
#  'beer brisket',
#  'underground baked chicken and potatoes',
#  'sriracha honey chicken',
#  'moist garlic roasted chicken',
#  'char siu chicken',
#  'traveling oven barbecued baby back ribs',
#  'kimberlymeaty meatloaf',
#  'mushroom sliders',
#  'garlic herb grilled pork tenderloin',
#  'lemonade pork chops',
#  'mean mr mustard steak',
#  'spicy honey mustard pork roast',
#  'dadfavorite detroit style roquefort burgers',
#  'perfect rib roast',
#  'marinated pork roast with apricot sauce',
#  'marinated chicken barbecue',
#  'peruvian style beer can chicken',
#  'apple radish bbq ribs',
#  'roast leg of lamb with orange juice and white wine',
#  'chef johnchicken underbrick',
#  'hobodelight',
#  ...]

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\60197\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Tokenize the input ingredients text
input_ingredients_tokens = word_tokenize(ingredients)

# Clean the input ingredients text
cleaned_input_ingredients = [word for word in input_ingredients_tokens if word.isalnum()]

# %%
# Create the input_bow variable
input_bow = dictionary.doc2bow(cleaned_input_ingredients)

# %%
from gensim import matutils

# Get the topic distribution of the input ingredients
input_topics = lda_model.get_document_topics(input_bow)

# Create empty list to store the similarity scores
similarity_scores = []

# For each document in the corpus
for doc in corpus:
    # Get the topic distribution of the document
    doc_topics = lda_model.get_document_topics(doc)
    # Calculate the similarity score between the input topics and the document topics
    similarity_scores.append(matutils.cossim(input_topics, doc_topics))

# %%
# # Get the topic distribution of the input ingredients
# input_topics = lda_model.get_document_topics(input_bow)

# # Create empty list to store the similarity scores
# similarity_scores = []

# # for each document in the corpus
# for doc in corpus:
#     # get the topic distribution of the document
#     doc_topics = lda_model.get_document_topics(doc)
#     # calculate the similarity score between the input topics and the document topics
#     similarity_scores.append(matutils.cossim(input_topics, doc_topics))

# %%
num_recommendations = 10

# %%
# Get the indexes of the most similar recipes
most_similar_indexes = sorted(range(len(similarity_scores)), key=lambda i: similarity_scores[i])[-num_recommendations:]

# Create empty list to store the recommended recipe names
recommended_recipe_names = []

# For each index in the most similar indexes
for index in most_similar_indexes:
# Append the recipe name to the list of recommended recipe names
    recommended_recipe_names.append(recipes.iloc[index]["recipe_name"])

# Create empty list to store the recommended recipes
recommended_recipes = []

# For each recommended recipe name
for recipe_name in recommended_recipe_names:
# Find the recipe in the original dataframe
    recipe = recipes[recipes["recipe_name"] == recipe_name]
# Append the recipe to the list of recommended recipes
    recommended_recipes.append(recipe)

# Print the details of recommended recipes
for recipe in recommended_recipes:
    print(recipe)
# Out:
#        Unnamed: 0                    recipe_name  \
# 21477       10377  chancepaleo breakfast sausage
#
#                                              ingredients  \
# 21477  ground pork^salt^ground turmeric^dried sage^dr...
#
#                                       cooking_directions  \
# 21477  {'directions': u'prep\n15 m\ncook\n8 m\nready ...
#
#                                               nutritions
# 21477  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0       recipe_name  \
# 19784        8272  willyjuicy steak
#
#                                              ingredients  \
# 19784  orange juice^thousand island salad dressing^wo...
#
#                                       cooking_directions  \
# 19784  {'directions': u'prep\n15 m\ncook\n20 m\nready...
#
#                                               nutritions
# 19784  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0                 recipe_name  \
# 16991        4719  chef johngrilled mojo beef
#
#                                              ingredients  \
# 16991  beef skirt steak^large navel orange juiced^lim...
#
#                                       cooking_directions  \
# 16991  {'directions': u"prep\n10 m\ncook\n8 m\nready ...
#
#                                               nutritions
# 16991  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0 recipe_name  \
# 12212       15770  bbq turkey
#
#                                              ingredients  \
# 12212  ['1 (15 pound) whole turkey, neck and giblets ...
#
#                                       cooking_directions  \
# 12212  ['\npreheat a gas grill for low heat.\n', '\nr...
#
#                                               nutritions
# 12212  [{'calories': '1294'}, {'fat': '77g '}, {'carb...
#        Unnamed: 0            recipe_name  \
# 22964       12248  beef and brie sliders
#
#                                              ingredients  \
# 22964  soft bread crumbs^voskos® nonfat blueberry gre...
#
#                                       cooking_directions  \
# 22964  {'directions': u'prep\n20 m\ncook\n10 m\nready...
#
#                                               nutritions
# 22964  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0                   recipe_name  \
# 44127       39128  grilled lemon pepper catfish
#
#                                              ingredients  \
# 44127  lemons juiced^sea salt^large cloves garlic^fil...
#
#                                       cooking_directions  \
# 44127  {'directions': u"prep\n20 m\ncook\n15 m\nready...
#
#                                               nutritions
# 44127  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0                                   recipe_name  \
# 24071       13654  bacon wrapped tenderloin with sage and lemon
#
#                                              ingredients  \
# 24071  boneless pork tenderloins^salt and ground blac...
#
#                                       cooking_directions  \
# 24071  {'directions': u'prep\n15 m\ncook\n40 m\nready...
#
#                                               nutritions
# 24071  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0            recipe_name  \
# 22109       11161  cocktail meatballs iv
#
#                                              ingredients  \
# 22109  ground beef^grape jelly^chili sauce^prepared m...
#
#                                       cooking_directions  \
# 22109  {'directions': u'prep\n30 m\ncook\n30 m\nready...
#
#                                               nutritions
# 22109  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0                          recipe_name  \
# 21315       10188  grilled coffee and cola skirt steak
#
#                                              ingredients  \
# 21315  large cloves garlic^fluid ounce) can^freshly b...
#
#                                       cooking_directions  \
# 21315  {'directions': u'prep\n10 m\ncook\n10 m\nready...
#
#                                               nutritions
# 21315  {u'niacin': {u'hascompletedata': false, u'name...
#        Unnamed: 0          recipe_name  \
# 16889        4588  grilled turkey legs
#
#                                              ingredients  \
# 16889  bottle lemon-lime flavored carbonated beverage...
#
#                                       cooking_directions  \
# 16889  {'directions': u'prep\n25 m\ncook\n50 m\nready...
#
#                                               nutritions
# 16889  {u'niacin': {u'hascompletedata': false, u'name...
